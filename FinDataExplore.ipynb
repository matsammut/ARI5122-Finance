# %%
# !pip install yfinance

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt

# %%
ticker = yf.Ticker('BA')

# %%
balsheet = ticker.get_balancesheet()
print(balsheet)
# Out:
#                                                2023-12-31     2022-12-31  \
# TreasurySharesNumber                          402746136.0    414671383.0
# OrdinarySharesNumber                          609515023.0    597589776.0
# ShareIssued                                  1012261159.0   1012261159.0
# NetDebt                                     39363000000.0  42181000000.0
# TotalDebt                                   52603000000.0  57277000000.0
# ...                                                   ...            ...
# OtherReceivables                             8441000000.0   8793000000.0
# AccountsReceivable                           2713000000.0   2628000000.0
# CashCashEquivalentsAndShortTermInvestments  15965000000.0  17220000000.0
# OtherShortTermInvestments                    3274000000.0   2606000000.0
# CashAndCashEquivalents                      12691000000.0  14614000000.0
#
#                                                2021-12-31     2020-12-31  \
# ...

# %%
balsheet.loc['TotalDebt']
# Out:
# 2023-12-31    52603000000.0
# 2022-12-31    57277000000.0
# 2021-12-31    58370000000.0
# 2020-12-31    63851000000.0
# 2019-12-31              NaN
# Name: TotalDebt, dtype: object

# %%
fin = ticker.get_financials()
print(fin)
# Out:
#                                                        2023-12-31  \
# TaxEffectOfUnusualItems                                10080000.0
# TaxRateForCalcs                                              0.21
# NormalizedEBITDA                                     2267000000.0
# TotalUnusualItems                                      48000000.0
# TotalUnusualItemsExcludingGoodwill                     48000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...  -2222000000.0
# ReconciledDepreciation                               1861000000.0
# ReconciledCostOfRevenue                             70070000000.0
# EBITDA                                               2315000000.0
# EBIT                                                  454000000.0
# NetInterestIncome                                   -2459000000.0
# InterestExpense                                      2459000000.0
# NormalizedIncome                                    -2259920000.0
# ...

# %%
ticker.get_info()
# Out:
# {'address1': '929 Long Bridge Drive',
#  'city': 'Arlington',
#  'state': 'VA',
#  'zip': '22202',
#  'country': 'United States',
#  'phone': '703-465-3500',
#  'website': 'https://www.boeing.com',
#  'industry': 'Aerospace & Defense',
#  'industryKey': 'aerospace-defense',
#  'industryDisp': 'Aerospace & Defense',
#  'sector': 'Industrials',
#  'sectorKey': 'industrials',
#  'sectorDisp': 'Industrials',
# ...

# %%
ticker.get_news()
# Out:
# [{'uuid': '4efc760e-d467-3855-8572-dfb0fddba84d',
#   'title': 'Boeing (BA) Rises As Market Takes a Dip: Key Facts',
#   'publisher': 'Zacks',
#   'link': 'https://finance.yahoo.com/news/boeing-ba-rises-market-takes-214519407.html',
#   'providerPublishTime': 1729201519,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/t6.OdXEVKQihFo9otNenfg--~B/aD01NjU7dz05MDA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/zacks.com/4f1a8d86cead9f96536efb147945dcc9',
#      'width': 900,
#      'height': 565,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/k5cTNiJKtV5aggvBgwLXAQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/zacks.com/4f1a8d86cead9f96536efb147945dcc9',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['BA']},
#  {'uuid': 'db350b72-700a-3f04-841d-861ba57914a0',
# ...

# %%
data = ticker.history('5y')

# %%
data.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-10-18 00:00:00-04:00  364.689301  365.035218  339.981354  339.981354
# 2019-10-21 00:00:00-04:00  329.001113  330.335318  320.610274  327.192474
# 2019-10-22 00:00:00-04:00  332.143982  337.490785  330.552775  333.063110
# 2019-10-23 00:00:00-04:00  340.969647  346.701878  332.568946  336.522217
# 2019-10-24 00:00:00-04:00  337.708221  341.701003  333.824109  340.524902
#
#                              Volume  Dividends  Stock Splits
# Date
# 2019-10-18 00:00:00-04:00  13544300        0.0           0.0
# 2019-10-21 00:00:00-04:00  15493100        0.0           0.0
# 2019-10-22 00:00:00-04:00   7949700        0.0           0.0
# 2019-10-23 00:00:00-04:00  10960800        0.0           0.0
# 2019-10-24 00:00:00-04:00   5382700        0.0           0.0

# %%
from matplotlib.pyplot import figure
figure(figsize=(10, 8), dpi=80)
data.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data.loc['2019-10-21']
# Out:
# Open            3.290011e+02
# High            3.303353e+02
# Low             3.206103e+02
# Close           3.271925e+02
# Volume          1.549310e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2019-10-21 00:00:00-04:00, dtype: float64

# %%
data.loc['2019-10-21':'2022-10-14']
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-10-21 00:00:00-04:00  329.001113  330.335318  320.610274  327.192474
# 2019-10-22 00:00:00-04:00  332.143982  337.490785  330.552775  333.063110
# 2019-10-23 00:00:00-04:00  340.969647  346.701878  332.568946  336.522217
# 2019-10-24 00:00:00-04:00  337.708221  341.701003  333.824109  340.524902
# 2019-10-25 00:00:00-04:00  338.913975  339.358700  334.940918  335.860046
# ...                               ...         ...         ...         ...
# 2022-10-10 00:00:00-04:00  131.419998  135.740005  130.199997  131.899994
# 2022-10-11 00:00:00-04:00  132.960007  135.360001  129.509995  131.570007
# 2022-10-12 00:00:00-04:00  128.429993  131.339996  127.860001  130.419998
# 2022-10-13 00:00:00-04:00  126.500000  134.699997  124.169998  132.399994
# 2022-10-14 00:00:00-04:00  135.589996  136.410004  131.369995  133.149994
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
data['Returns'] = np.log(data.Close).diff()

# %%
data.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-10-11 00:00:00-04:00  146.300003  151.119995  146.300003  151.020004
# 2024-10-14 00:00:00-04:00  148.000000  150.089996  146.020004  148.990005
# 2024-10-15 00:00:00-04:00  150.500000  153.949997  148.550003  152.350006
# 2024-10-16 00:00:00-04:00  151.910004  154.990005  151.339996  154.899994
# 2024-10-17 00:00:00-04:00  155.000000  157.139999  154.250000  155.309998
#
#                              Volume  Dividends  Stock Splits   Returns
# Date
# 2024-10-11 00:00:00-04:00  10688600        0.0           0.0  0.029568
# 2024-10-14 00:00:00-04:00   9737000        0.0           0.0 -0.013533
# 2024-10-15 00:00:00-04:00  11241700        0.0           0.0  0.022301
# 2024-10-16 00:00:00-04:00   8356200        0.0           0.0  0.016599
# 2024-10-17 00:00:00-04:00   6287400        0.0           0.0  0.002643

# %%
np.log(148.990005) - np.log(151.020004)
# Out:
# -0.013533081703291039

# %%
151.020004 * np.exp(-0.013533)
# Out:
# 148.99001717297418

# %%
figure(figsize=(10, 8), dpi=80)
data.Returns.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#figure(figsize=(10, 8), dpi=80)
data.Close.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
figure(figsize=(10, 8), dpi=80)
data.Returns.cumsum().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
figure(figsize=(10, 8), dpi=80)
data.Returns.rolling(10).std().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data.tail()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-10-11 00:00:00-04:00  146.300003  151.119995  146.300003  151.020004
# 2024-10-14 00:00:00-04:00  148.000000  150.089996  146.020004  148.990005
# 2024-10-15 00:00:00-04:00  150.500000  153.949997  148.550003  152.350006
# 2024-10-16 00:00:00-04:00  151.910004  154.990005  151.339996  154.899994
# 2024-10-17 00:00:00-04:00  155.000000  157.139999  154.250000  155.309998
#
#                              Volume  Dividends  Stock Splits   Returns
# Date
# 2024-10-11 00:00:00-04:00  10688600        0.0           0.0  0.029568
# 2024-10-14 00:00:00-04:00   9737000        0.0           0.0 -0.013533
# 2024-10-15 00:00:00-04:00  11241700        0.0           0.0  0.022301
# 2024-10-16 00:00:00-04:00   8356200        0.0           0.0  0.016599
# 2024-10-17 00:00:00-04:00   6287400        0.0           0.0  0.002643

# %%
151.020004 * np.exp(-0.013533+0.022301+0.016599+0.002643)
# Out:
# 155.3098734658755
